# %%
import optuna
from pathlib import Path
import sqlite3
import pandas as pd

# %%
sqlite_file = Path("/Users/thomassimader/Documents/NIRB/data/09/optuna_dbTemperature.sqlite3")

# %%
# Query to select all rows from the 'studies' table
# Connect to the SQLite database
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute("SELECT * FROM studies")
# Fetch all results
rows = cursor.fetchall()
# Get column names
column_names = [description[0] for description in cursor.description]
# Optionally, display as a DataFrame for better readability
df = pd.DataFrame(rows, columns=column_names)
print(df)
conn.close()
# Out:
#    study_id study_name
# 0         1     sweep1

# %%
storage = f"sqlite:///{sqlite_file}"
loaded_study = optuna.load_study(study_name="sweep1", storage= storage)

# %%
df_opt = loaded_study.trials_dataframe()
df_opt
# Out:
#    number        value             datetime_start          datetime_complete  \
# 0       0    11.829391 2025-06-18 17:38:11.973531 2025-06-18 19:13:13.532631
# 1       1  1685.528809 2025-06-18 17:38:11.976104 2025-06-18 19:13:14.297818
# 2       2   338.592133 2025-06-18 19:13:14.453954 2025-06-18 22:40:50.063737
# 3       3  2572.057861 2025-06-18 19:13:14.456762 2025-06-18 22:40:50.287108
# 4       4    59.445335 2025-06-18 22:40:50.522903 2025-06-19 00:02:04.303706
# 5       5    14.609913 2025-06-18 22:40:50.523416 2025-06-19 00:02:04.337104
# 6       6          NaN 2025-06-19 00:02:04.406903                        NaT
# 7       7          NaN 2025-06-19 00:02:04.407662                        NaT
#
#                 duration  params_accuracy params_activation  \
# 0 0 days 01:35:01.559100         0.000010              relu
# 1 0 days 01:35:02.321714         0.000001           sigmoid
# 2 0 days 03:27:35.609783         0.000001              tanh
# 3 0 days 03:27:35.830346         0.000010              tanh
# 4 0 days 01:21:13.780803         0.000010              tanh
# 5 0 days 01:21:13.813688         0.000010              relu
# 6                    NaT         0.000010        leaky_relu
# 7                    NaT         0.000010              tanh
#
#    params_batch_size  params_hidden1  params_hidden6  \
# 0                144              10              78
# 1                 92              32              88
# 2                119              97              68
# 3                 24              98              50
# 4                101              12              94
# 5                108              50              82
# 6                 65              11              62
# 7                109              88              60
#
#    params_hidden_layers_betw0  params_hidden_layers_betw1  \
# 0                          94                         276
# 1                         292                         272
# 2                          74                         156
# 3                         178                         240
# 4                          88                         214
# 5                          50                         246
# 6                         150                         154
# 7                         254                         210
#
#    params_hidden_layers_betw2  params_hidden_layers_betw3  params_lr  \
# 0                         NaN                         NaN   0.000106
# 1                       196.0                       212.0   0.000015
# 2                       210.0                       226.0   0.000048
# 3                         NaN                         NaN   0.000018
# 4                         NaN                         NaN   0.000124
# 5                       246.0                         NaN   0.000005
# 6                       144.0                       192.0   0.000201
# 7                       238.0                         NaN   0.000322
#
#    params_num_inbetw_layers params_scaler_features params_scaler_output  \
# 0                         2                   Mean                 mean
# 1                         4           Standardizer    min_max_init_grad
# 2                         4                Min_Max                 mean
# 3                         2                   Mean    min_max_init_grad
# 4                         2                   Mean    min_max_init_grad
# 5                         3           Standardizer                 mean
# 6                         4                Min_Max    min_max_init_grad
# 7                         3                   Mean                 mean
#
#    user_attrs_val_loss     state
# 0            18.165440  COMPLETE
# 1          1690.067627  COMPLETE
# 2           336.286285  COMPLETE
# 3          2581.276123  COMPLETE
# 4            67.903114  COMPLETE
# 5            19.015348  COMPLETE
# 6                  NaN   RUNNING
# 7                  NaN   RUNNING

# %%
# # Path to your .db file
# # Query to list all table names
# cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
# tables = cursor.fetchall()

# # Extract table names from tuples
# table_names = [table[0] for table in tables]
# table_names

# %%
db_name = "results_allEntropy.db" #"results_all_zero_crossingEntropyNum.db"
db_name = "results_allTemperature.db" #"results_all_zero_crossingEntropyNum.db"

sqlite_file = Path().cwd().parent / f"data/09/{db_name}" #     _zero_crossing.db" #results_all_zc.db"
conn = sqlite3.connect(sqlite_file)
query = "SELECT * FROM nirb_results"
df = pd.read_sql_query(query, conn)
# Close connection
conn.close()

# %%
df.sort_values("Entropy_MSE_test",ascending=True)
df
# Out:
#     id               norm  Version  \
# 0    1               mean  trial_0
# 1    2               mean  trial_0
# 2    3               mean  trial_0
# 3    4               mean  trial_0
# 4    5  min_max_init_grad  trial_1
# 5    6  min_max_init_grad  trial_1
# 6    7  min_max_init_grad  trial_1
# 7    8  min_max_init_grad  trial_1
# 8    9               mean  trial_2
# 9   10               mean  trial_2
# 10  11               mean  trial_2
# 11  12               mean  trial_2
# 12  13  min_max_init_grad  trial_3
# 13  14  min_max_init_grad  trial_3
# 14  15  min_max_init_grad  trial_3
# 15  16  min_max_init_grad  trial_3
# 16  17  min_max_init_grad  trial_4
# 17  18  min_max_init_grad  trial_4
# 18  19  min_max_init_grad  trial_4
# 19  20  min_max_init_grad  trial_4
# 20  21               mean  trial_5
# 21  22               mean  trial_5
# 22  23               mean  trial_5
#
#                                       feature_scaling  Accuracy  Q2_scaled  \
# 0   <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.076869
# 1   <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.076921
# 2   <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.077032
# 3   <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.077071
# 4   <src.pod.normalizer.Standardizer object at 0x1...  0.000001   0.175242
# 5   <src.pod.normalizer.Standardizer object at 0x1...  0.000001   0.174550
# 6   <src.pod.normalizer.Standardizer object at 0x1...  0.000001   0.173860
# 7   <src.pod.normalizer.Standardizer object at 0x1...  0.000001   0.173432
# 8   <src.pod.normalizer.MinMaxNormalizer object at...  0.000001   0.081994
# 9   <src.pod.normalizer.MinMaxNormalizer object at...  0.000001   0.082050
# 10  <src.pod.normalizer.MinMaxNormalizer object at...  0.000001   0.082106
# 11  <src.pod.normalizer.MinMaxNormalizer object at...  0.000001   0.082109
# 12  <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.189553
# 13  <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.189444
# 14  <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.189335
# 15  <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.189276
# 16  <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.306362
# 17  <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.306362
# 18  <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.306362
# 19  <src.pod.normalizer.MeanNormalizer object at 0...  0.000010   0.306362
# 20  <src.pod.normalizer.Standardizer object at 0x1...  0.000010   0.077283
# 21  <src.pod.normalizer.Standardizer object at 0x1...  0.000010   0.077297
# 22  <src.pod.normalizer.Standardizer object at 0x1...  0.000010   0.077311
#
#     Q2_unscaled  R2_scaled  R2_unscaled  Epoch  Global_step  Entropy_MSE_test  \
# 0   1968.013547   0.077270  1978.280803  17499        17500          1.441344
# 1   1969.354523   0.077324  1979.663380  18499        18500          1.441652
# 2   1972.190706   0.077436  1982.531458  21499        21500          1.442134
