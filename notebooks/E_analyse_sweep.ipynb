# %%
import optuna
from pathlib import Path
import sqlite3
import pandas as pd

# %%
sqlite_file = Path("/Users/thomassimader/Library/CloudStorage/OneDrive-geomeconGmbH/PhD/NIRB/data/07/optuna_db.sqlite3")

# %%
# Query to select all rows from the 'studies' table
# Connect to the SQLite database
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute("SELECT * FROM studies")
# Fetch all results
rows = cursor.fetchall()
# Get column names
column_names = [description[0] for description in cursor.description]
# Optionally, display as a DataFrame for better readability
df = pd.DataFrame(rows, columns=column_names)
print(df)
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[23], line 5
#       3 conn = sqlite3.connect(sqlite_file)
#       4 cursor = conn.cursor()
# ----> 5 cursor.execute("SELECT * FROM studies")
#       6 # Fetch all results
#       7 rows = cursor.fetchall()
#
# OperationalError: no such table: studies

# %%
storage = f"sqlite:///{sqlite_file}"
loaded_study = optuna.load_study(study_name="sweep", storage= storage)

# %%
df_opt = loaded_study.trials_dataframe()
df_opt
# Out:
#      number     value             datetime_start          datetime_complete  \
# 0         0  0.341413 2025-06-07 12:58:27.257043 2025-06-07 14:05:45.127177
# 1         1  2.075645 2025-06-07 12:58:27.258507 2025-06-07 14:15:46.749072
# 2         2  2.242180 2025-06-07 12:58:27.266177 2025-06-07 14:17:50.736695
# 3         3  7.293092 2025-06-07 12:58:27.269454 2025-06-07 14:18:34.473823
# 4         4  1.640649 2025-06-07 14:05:45.628457 2025-06-07 15:24:32.301575
# ..      ...       ...                        ...                        ...
# 145     145  0.076562 2025-06-09 08:10:00.998446 2025-06-09 09:30:09.545327
# 146     146  0.008641 2025-06-09 08:18:54.340779 2025-06-09 09:39:03.405084
# 147     147  0.001002 2025-06-09 08:49:43.929055 2025-06-09 10:09:52.892749
# 148     148  0.000108 2025-06-09 09:26:14.097256 2025-06-09 10:30:45.303691
# 149     149  0.003740 2025-06-09 09:30:09.943117 2025-06-09 10:31:28.360491
#
#                   duration  params_accuracy params_activation  \
# 0   0 days 01:07:17.870134          0.00001              tanh
# 1   0 days 01:17:19.490565          0.00001              tanh
# 2   0 days 01:19:23.470518          0.00001        leaky_relu
# 3   0 days 01:20:07.204369          0.00001           sigmoid
# 4   0 days 01:18:46.673118          0.00001           sigmoid
# ..                     ...              ...               ...
# 145 0 days 01:20:08.546881          0.00001        leaky_relu
# 146 0 days 01:20:09.064305          0.00001        leaky_relu
# 147 0 days 01:20:08.963694          0.00001        leaky_relu
# 148 0 days 01:04:31.206435          0.00001        leaky_relu
# 149 0 days 01:01:18.417374          0.00001              relu
#
#      params_batch_size  params_hidden_layers_betw0  \
# 0                   46                         234
# 1                   42                         240
# 2                   24                          96
# 3                   85                         164
# 4                   57                         340
# ..                 ...                         ...
# 145                 84                         222
# 146                 85                         362
# 147                 78                         364
# 148                 85                         364
# 149                 78                         366
#
#      params_hidden_layers_betw1  params_hidden_layers_betw2  \
# 0                         226.0                         NaN
# 1                         264.0                        82.0
# 2                         272.0                       238.0
# 3                         264.0                        54.0
# 4                         284.0                       104.0
# ..                          ...                         ...
# 145                       382.0                         NaN
# 146                       318.0                         NaN
# 147                       180.0                         NaN
# 148                       180.0                         NaN
# 149                       178.0                         NaN
#
#      params_hidden_layers_betw3  params_hiden1  params_hiden6  params_lr  \
# 0                           NaN             77            234   0.000034
# 1                           NaN            234             34   0.000447
# 2                         250.0            277             92   0.000137
# 3                         126.0            153             86   0.001760
# 4                           NaN              4             32   0.000660
# ..                          ...            ...            ...        ...
# 145                         NaN            300            292   0.001126
# 146                         NaN            300            262   0.001784
# 147                         NaN            255            262   0.001157
# 148                         NaN            276            270   0.001078
# 149                         NaN            255            270   0.001681
#
#      params_num_inbetw_layers params_scaler_features params_scaler_output  \
# 0                           2                Min_Max                 mean
# 1                           3           Standardizer    min_max_init_grad
# 2                           4                Min_Max    min_max_init_grad
# 3                           4                Min_Max    min_max_init_grad
# 4                           3                   Mean    min_max_init_grad
# ..                        ...                    ...                  ...
# 145                         2                   Mean                 mean
# 146                         2                   Mean                 mean
# 147                         2                   Mean                 mean
# 148                         2                   Mean                 mean
# 149                         2                   Mean                 mean
#
#      user_attrs_val_loss     state
# 0               0.790889  COMPLETE
# 1               3.226526  COMPLETE
# 2               2.916799  COMPLETE
# 3               6.408610  COMPLETE
# 4               2.377337  COMPLETE
# ..                   ...       ...
# 145             0.934458  COMPLETE
# 146             0.916595  COMPLETE
# 147             0.961907  COMPLETE
# 148             0.987353  COMPLETE
# 149             1.142223  COMPLETE
#
# [150 rows x 20 columns]

# %%
# # Path to your .db file
# # Query to list all table names
# cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
# tables = cursor.fetchall()

# # Extract table names from tuples
# table_names = [table[0] for table in tables]
# table_names

# %%
db_name = "results_allEntropy.db" #"results_all_zero_crossingEntropyNum.db"
# db_name = "results_allTemperature.db" #"results_all_zero_crossingEntropyNum.db"

sqlite_file = Path().cwd().parent / f"data/08/{db_name}" #     _zero_crossing.db" #results_all_zc.db"
conn = sqlite3.connect(sqlite_file)
query = "SELECT * FROM nirb_results"
df = pd.read_sql_query(query, conn)
# Close connection
conn.close()

# %%
df.sort_values("Entropy_MSE_test",ascending=True)
df
# Out:
#       id     norm   Version  \
# 0      1  min_max  trial_10
# 1      2  min_max  trial_10
# 2      3  min_max  trial_10
# 3      4  min_max  trial_10
# 4      5  min_max  trial_11
# ..   ...      ...       ...
# 106  107  min_max   trial_8
# 107  108     mean   trial_9
# 108  109     mean   trial_9
# 109  110     mean   trial_9
# 110  111     mean   trial_9
#
#                                        feature_scaling  Accuracy  Q2_scaled  \
# 0    <src.pod.normalizer.MinMaxNormalizer object at...   0.00001   0.000233
# 1    <src.pod.normalizer.MinMaxNormalizer object at...   0.00001   0.000232
# 2    <src.pod.normalizer.MinMaxNormalizer object at...   0.00001   0.000231
# 3    <src.pod.normalizer.MinMaxNormalizer object at...   0.00001   0.000231
# 4    <src.pod.normalizer.MinMaxNormalizer object at...   0.00001   0.000250
# ..                                                 ...       ...        ...
# 106  <src.pod.normalizer.MeanNormalizer object at 0...   0.00001   0.000270
# 107  <src.pod.normalizer.MeanNormalizer object at 0...   0.00001   0.000178
# 108  <src.pod.normalizer.MeanNormalizer object at 0...   0.00001   0.000178
# 109  <src.pod.normalizer.MeanNormalizer object at 0...   0.00001   0.000179
# 110  <src.pod.normalizer.MeanNormalizer object at 0...   0.00001   0.000179
#
#       Q2_unscaled  R2_scaled   R2_unscaled  Epoch  Global_step  \
# 0    4.969029e-16   0.000249  5.306562e-16  48999        98000
# 1    4.952490e-16   0.000248  5.291660e-16  49749        99500
# 2    4.928102e-16   0.000248  5.287054e-16  49999       100000
# 3    4.928102e-16   0.000248  5.287054e-16  49999       100000
# 4    5.323475e-16   0.000251  5.348149e-16  14071        98500
# ..            ...        ...           ...    ...          ...
# 106  5.749177e-16   0.000078  1.671497e-16  33333       100000
# 107  3.798456e-16   0.000122  2.592565e-16  19599        98000
# 108  3.791357e-16   0.000120  2.553353e-16  19899        99500
# 109  3.803815e-16   0.000119  2.540624e-16  19999       100000
# 110  3.803815e-16   0.000119  2.540624e-16  19999       100000
#
#      Entropy_MSE_test  Entropy_R2_test  Entropy_MSE_train  Entropy_R2_train  \
# 0            0.003345         0.810571           0.002859          0.868184
# 1            0.003326         0.810843           0.002849          0.868703
# 2            0.003327         0.809408           0.002845          0.869003
# 3            0.003327         0.809408           0.002845          0.869003
# 4            0.003168         0.828369           0.002612          0.880460
# ..                ...              ...                ...               ...
# 106          0.003422         0.816066           0.001015          0.957132
# 107          0.003385         0.823622           0.002025          0.908945
# 108          0.003350         0.825934           0.002023          0.908969
# 109          0.003325         0.827602           0.002014          0.909450
# 110          0.003325         0.827602           0.002014          0.909450
#
#                                                   Path
# 0    /Users/thomassimader/Library/CloudStorage/OneD...
# 1    /Users/thomassimader/Library/CloudStorage/OneD...
# 2    /Users/thomassimader/Library/CloudStorage/OneD...
# 3    /Users/thomassimader/Library/CloudStorage/OneD...
# 4    /Users/thomassimader/Library/CloudStorage/OneD...
# ..                                                 ...
# 106  /Users/thomassimader/Library/CloudStorage/OneD...
# 107  /Users/thomassimader/Library/CloudStorage/OneD...
# 108  /Users/thomassimader/Library/CloudStorage/OneD...
# 109  /Users/thomassimader/Library/CloudStorage/OneD...
# 110  /Users/thomassimader/Library/CloudStorage/OneD...
#
# [111 rows x 16 columns]

# %%
print(str(df.columns))
# Out:
# Index(['id', 'norm', 'Version', 'Accuracy', 'Q2_scaled', 'Q2_unscaled',
#        'R2_scaled', 'R2_unscaled', 'Epoch', 'Global_step', 'Entropy_MSE_test',
#        'Entropy_R2_test', 'Entropy_MSE_train', 'Entropy_R2_train', 'Path'],
#       dtype='object')
