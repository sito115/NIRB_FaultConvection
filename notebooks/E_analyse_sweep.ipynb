# %%
import optuna
from pathlib import Path
import sqlite3
import pandas as pd

# %%
sqlite_file = Path("/Users/thomassimader/Documents/NIRB/data/01/db_total_new.sqlite3")

# %%
# Query to select all rows from the 'studies' table
# Connect to the SQLite database
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute("SELECT * FROM studies")
# Fetch all results
rows = cursor.fetchall()
# Get column names
column_names = [description[0] for description in cursor.description]
# Optionally, display as a DataFrame for better readability
df = pd.DataFrame(rows, columns=column_names)
print(df)
conn.close()
# Out:
#    study_id study_name
# 0         1     sweep1

# %%
storage = f"sqlite:///{sqlite_file}"
loaded_study = optuna.load_study(study_name="sweep1", storage= storage)

# %%
df_opt = loaded_study.trials_dataframe()
df_opt
# Out:
#     number     value             datetime_start          datetime_complete  \
# 0        0  5.557637 2025-05-30 17:15:42.044297 2025-05-30 17:55:55.825037
# 1        1  3.663707 2025-05-30 17:15:42.046155 2025-05-30 17:55:55.833256
# 2        2  2.774770 2025-05-30 17:15:42.127212 2025-05-30 17:55:55.825637
# 3        3  3.410308 2025-05-30 17:55:56.122553 2025-05-30 18:36:09.501830
# 4        4  5.704465 2025-05-30 17:55:56.123829 2025-05-30 18:36:09.471987
# ..     ...       ...                        ...                        ...
# 92      92  1.099530 2025-05-31 12:28:45.438002 2025-05-31 13:08:55.774781
# 93      93  0.878642 2025-05-31 12:29:59.002260 2025-05-31 13:10:08.996723
# 94      94       NaN 2025-05-31 13:02:31.836660                        NaT
# 95      95       NaN 2025-05-31 13:08:55.984523                        NaT
# 96      96       NaN 2025-05-31 13:10:09.045094                        NaT
#
#                  duration params_activation  params_batch_size  \
# 0  0 days 00:40:13.780740        leaky_relu                527
# 1  0 days 00:40:13.787101              relu                111
# 2  0 days 00:40:13.698425           sigmoid                398
# 3  0 days 00:40:13.379277           sigmoid                525
# 4  0 days 00:40:13.348158              relu                520
# ..                    ...               ...                ...
# 92 0 days 00:40:10.336779           sigmoid                390
# 93 0 days 00:40:09.994463           sigmoid                185
# 94                    NaT           sigmoid                174
# 95                    NaT           sigmoid                482
# 96                    NaT           sigmoid                116
#
#     params_hidden_layers_betw0  params_hidden_layers_betw1  \
# 0                          118                         NaN
# 1                          366                       372.0
# 2                          356                       342.0
# 3                          152                       178.0
# 4                          144                         NaN
# ..                         ...                         ...
# 92                         362                       252.0
# 93                         382                       252.0
# 94                         400                       202.0
# 95                         400                       204.0
# 96                         400                       328.0
#
#     params_hidden_layers_betw2  params_hidden_layers_betw3  \
# 0                          NaN                         NaN
# 1                        180.0                         NaN
# 2                          NaN                         NaN
# 3                        376.0                        94.0
# 4                          NaN                         NaN
# ..                         ...                         ...
# 92                       146.0                       126.0
# 93                       222.0                        82.0
# 94                       142.0                       122.0
# 95                       220.0                        80.0
# 96                       132.0                        80.0
#
#     params_hidden_layers_betw4  params_hiden1  params_hiden6  params_lr  \
# 0                          NaN            206            250   0.000855
# 1                          NaN            260            290   0.000264
# 2                          NaN            117            254   0.000314
# 3                        116.0            204             64   0.000109
# 4                          NaN            258            198   0.000296
# ..                         ...            ...            ...        ...
# 92                       304.0            277            272   0.000013
# 93                       340.0            274            146   0.000058
# 94                       328.0            276            264   0.000062
# 95                       346.0            124            148   0.000061
# 96                       330.0            122            144   0.000008
#
#    params_normalization  params_num_inbetw_layers  user_attrs_train_loss  \
# 0     min_max_init_grad                         1               0.458066
# 1     min_max_init_grad                         3               0.393751
# 2        mean_init_grad                         2               0.005562
# 3     min_max_init_grad                         5               4.200490
# 4     min_max_init_grad                         1               0.906896
# ..                  ...                       ...                    ...
# 92       mean_init_grad                         5               1.253421
# 93       mean_init_grad                         5               1.271756
# 94       mean_init_grad                         5                    NaN
# 95       mean_init_grad                         5                    NaN
# 96       mean_init_grad                         5                    NaN
#
#        state
# 0   COMPLETE
# 1   COMPLETE
# 2   COMPLETE
# 3   COMPLETE
# 4   COMPLETE
# ..       ...
# 92  COMPLETE
# 93  COMPLETE
# 94   RUNNING
# 95   RUNNING
# 96   RUNNING
#
# [97 rows x 19 columns]

# %%
# # Path to your .db file
# # Query to list all table names
# cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
# tables = cursor.fetchall()

# # Extract table names from tuples
# table_names = [table[0] for table in tables]
# table_names
# Out:
# ['studies',
#  'version_info',
#  'study_directions',
#  'study_user_attributes',
#  'study_system_attributes',
#  'trials',
#  'trial_user_attributes',
#  'trial_system_attributes',
#  'trial_params',
#  'trial_values',
#  'trial_intermediate_values',
#  'trial_heartbeats',
#  'alembic_version']

# %%
sqlite_file = Path("/Users/thomassimader/Documents/NIRB/data/01/results_all.db")
conn = sqlite3.connect(sqlite_file)
query = "SELECT * FROM nirb_results"
df = pd.read_sql_query(query, conn)
# Close connection
conn.close()

# %%
df
# Out:
#      id               norm     Version  Accuracy  Q2_scaled  Q2_unscaled  \
# 0     1  min_max_init_grad   version_0  0.000010   0.050892  1168.050969
# 1     2  min_max_init_grad   version_1  0.000010   0.050923  1168.782044
# 2     3  min_max_init_grad  version_10  0.000010   0.003711    85.177161
# 3     4  min_max_init_grad  version_11  0.000010   0.003734    85.693597
# 4     9  min_max_init_grad  version_12  0.000010   0.004882   112.055233
# ..  ...                ...         ...       ...        ...          ...
# 90   96               mean   version_6  0.000001   0.037714  1501.778969
# 91   97               mean   version_6  0.000001   0.020146   802.223399
# 92   98               mean   version_6  0.000001   0.020143   802.085091
# 93   99               mean   version_6  0.000001   0.023700   943.723647
# 94  100               mean   version_6  0.000001   0.039318  1565.635977
#
#     R2_scaled  R2_unscaled  Entropy_MSE_test  Entropy_R2_test  \
# 0    0.225939     4.076828          0.783597        -0.804684
# 1    0.225954     4.186943          0.799024        -0.763141
# 2    0.225805     0.285663          0.011773        -0.789344
# 3    0.225806     0.289054          0.011710        -0.789341
# 4    0.225826     0.000034          0.005359         0.778490
# ..        ...          ...               ...              ...
# 90   0.051941     4.466742          0.781543        -0.698131
# 91   0.051925     3.245106          0.170466        -0.773083
# 92   0.051925     3.241857          0.170529        -0.774613
# 93   0.051935     3.719508          0.247852        -0.671477
# 94   0.051947     4.631345          0.688348        -0.722722
#
#     Entropy_MSE_train  Entropy_R2_train                       Path
# 0        1.638974e-03               1.0                       None
# 1        2.294201e-03               1.0                       None
# 2        7.901645e-05               1.0                       None
# 3        7.857148e-05               1.0                       None
# 4        1.064170e-11               1.0                       None
# ..                ...               ...                        ...
# 90       2.712805e-03               1.0   epoch=7999-val_loss=0.16
# 91       1.411899e-03               1.0                       last
# 92       1.415391e-03               1.0  epoch=49999-val_loss=0.03
# 93       1.260173e-03               1.0  epoch=25999-val_loss=0.55
# 94       2.295609e-03               1.0  epoch=10999-val_loss=0.26
#
# [95 rows x 13 columns]
